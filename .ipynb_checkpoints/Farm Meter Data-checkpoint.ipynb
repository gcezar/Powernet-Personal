# %%
import os
import pandas as pd
import numpy as np
import csv
import glob
import mpld3
mpld3.enable_notebook()
# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,5)

# %%
path = '/Users/gcezar/Documents/Powernet/Farm/BES_Input_D3MI'
files = []
all_files = glob.glob(os.path.join(path, "*.csv"))
            
# file = '~/Documents/Powernet/Farm/BES_Input_D3MI/'
# data = pd.read_csv(file)
# data.head()

# %%
all_files[1]
# Out:
# '/Users/gcezar/Documents/Powernet/Farm/BES_Input_D3MI/BES_Report_D3MI_0330174190_20190918.csv'

# %%
file = all_files[1]
data = pd.read_csv(file, names=list(range(0,6)))
data.head(15)
# Out:
#                                0                    1            2  \
# 0   DOUBLE DIAMOND DAIRY & RANCH                  NaN          NaN
# 1            505 E WASHINGTON RD                  NaN          NaN
# 2            Account# 3423052964                  NaN          NaN
# 3              SA_ID# 0330174190                  NaN          NaN
# 4             SP_ID# 7241403005   MTR_NBR# 1010113707          NaN
# 5                     08-30-2019          09-18-2019           NaN
# 6                          sa_id                sp_id  ener_dir_cd
# 7                     0330174190           7241403005            D
# 8                     0330174190           7241403005            D
# 9                     0330174190           7241403005            D
# 10                    0330174190           7241403005            D
# 11                    0330174190           7241403005            D
# 12                    0330174190           7241403005            D
# 13                    0330174190           7241403005            D
# 14                    0330174190           7241403005            D
#
#                       3    4           5
# 0                   NaN  NaN         NaN
# 1                   NaN  NaN         NaN
# 2                   NaN  NaN         NaN
# 3                   NaN  NaN         NaN
# 4                   NaN  NaN         NaN
# 5                   NaN  NaN         NaN
# 6   elec_intvl_end_dttm  uom   usgamount
# 7   2019-08-30 00:15:00  KWH  24.0000000
# 8   2019-08-30 00:30:00  KWH  34.3200000
# 9   2019-08-30 00:45:00  KWH  38.6400000
# 10  2019-08-30 01:00:00  KWH  27.4800000
# 11  2019-08-30 01:15:00  KWH  15.7200000
# 12  2019-08-30 01:30:00  KWH  5.52000000
# 13  2019-08-30 01:45:00  KWH  29.2800000
# 14  2019-08-30 02:00:00  KWH  29.2800000

# %%
# Finding index of where the file starts
idx_start = data.loc[data[0]=='sa_id'].index[0]
data.columns = list(data.iloc[6])

# %%
data.drop(['elec_intvl_end_dttm'], axis=1, inplace=True)

# %%
data.head(15)
# Out:
#                           sa_id       sp_id ener_dir_cd  uom   usgamount
# datetime
# 2019-08-30 00:15:00  0330174190  7241403005           D  KWH  24.0000000
# 2019-08-30 00:30:00  0330174190  7241403005           D  KWH  34.3200000
# 2019-08-30 00:45:00  0330174190  7241403005           D  KWH  38.6400000
# 2019-08-30 01:00:00  0330174190  7241403005           D  KWH  27.4800000
# 2019-08-30 01:15:00  0330174190  7241403005           D  KWH  15.7200000
# 2019-08-30 01:30:00  0330174190  7241403005           D  KWH  5.52000000
# 2019-08-30 01:45:00  0330174190  7241403005           D  KWH  29.2800000
# 2019-08-30 02:00:00  0330174190  7241403005           D  KWH  29.2800000
# 2019-08-30 02:15:00  0330174190  7241403005           D  KWH  31.2000000
# 2019-08-30 02:30:00  0330174190  7241403005           D  KWH  21.6000000
# 2019-08-30 02:45:00  0330174190  7241403005           D  KWH  16.6800000
# 2019-08-30 03:00:00  0330174190  7241403005           D  KWH  13.3200000
# 2019-08-30 03:15:00  0330174190  7241403005           D  KWH  14.7600000
# 2019-08-30 03:30:00  0330174190  7241403005           D  KWH  14.0400000
# 2019-08-30 03:45:00  0330174190  7241403005           D  KWH  15.6000000

# %%
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
def list_files_in_folder(path='/Users/gcezar/Documents/Powernet/Farm/BES_Input_D3MI'):
    files = []
    return glob.glob(os.path.join(path, "*.csv"))
    
def load_file(file_path):
    data = pd.read_csv(file_path, names=list(range(0,6)))
    # Finding index of where the file starts
    idx_start = data.loc[data[0]=='sa_id'].index[0]
    data.columns = list(data.iloc[idx_start])
    # droping headers
    lst = list(range(0,idx_start+1))
    data.drop(data.index[lst], inplace=True)
    # setting datetime as index
    data['datetime'] = pd.to_datetime(data['elec_intvl_end_dttm'])
    data['date'] = data['datetime'].dt.date
    data['hour'] = data['datetime'].dt.hour
    data.set_index('datetime', inplace=True)
    data.drop(['elec_intvl_end_dttm'], axis=1, inplace=True)
    # making kwh float
    data['usgamount'] = data['usgamount'].astype(float)
    data
    return data

# %%
files = list_files_in_folder()

# %%
df = load_file(files[1])
df.columns
# Out:
# Index(['sa_id', 'sp_id', 'ener_dir_cd', 'uom', 'usgamount', 'date', 'hour'], dtype='object')

# %%
df.head()
# Out:
#                           sa_id       sp_id ener_dir_cd  uom  usgamount  \
# datetime
# 2019-08-30 00:15:00  0330174190  7241403005           D  KWH      24.00
# 2019-08-30 00:30:00  0330174190  7241403005           D  KWH      34.32
# 2019-08-30 00:45:00  0330174190  7241403005           D  KWH      38.64
# 2019-08-30 01:00:00  0330174190  7241403005           D  KWH      27.48
# 2019-08-30 01:15:00  0330174190  7241403005           D  KWH      15.72
#
#                            date  hour
# datetime
# 2019-08-30 00:15:00  2019-08-30     0
# 2019-08-30 00:30:00  2019-08-30     0
# 2019-08-30 00:45:00  2019-08-30     0
# 2019-08-30 01:00:00  2019-08-30     1
# 2019-08-30 01:15:00  2019-08-30     1

# %%
df.plot(y='usgamount')
plt.show()
# df.head()

# usage.plot()
# ax.set_ylabel('Energy [kWh]')
# plt.show()

# %%
daily_avg = df.usgamount.resample('D').mean()
daily_avg.plot(marker='x')

# %%
df_date = df.groupby('date')
df_date_hour = df.groupby(['date', 'hour'])

# %%
# Listing unique elements from groups [day]
lst_group_day = df.date.unique()
lst_group_day[0]
# Out:
# datetime.date(2019, 8, 30)

# %%
# getting elements from groups
day = df_date.get_group(lst_group_day[0])
day.plot(x='datetime', y='usgamount', marker='x')
plt.show()

# %%
new_day_df = df_date[['datetime', 'usgamount']]
new_day_df.set_index('datetime', inplace=True)
avg = new_day_df.resample('D').mean()
avg
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-49a61dd18223> in <module>
#       1 new_day_df = df_date[['datetime', 'usgamount']]
# ----> 2 new_day_df.set_index('datetime', inplace=True)
#       3 avg = new_day_df.resample('D').mean()
#       4 avg
#
# /anaconda2/envs/venv_egauge/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# /anaconda2/envs/venv_egauge/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'set_index' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
for idx,i in enumerate(files):
    load_file(i)

# %%
# Out:
#          sa_id       sp_id ener_dir_cd  uom  usgamount            datetime  \
# 7   0330174190  7241403005           D  KWH      24.00 2019-08-30 00:15:00
# 8   0330174190  7241403005           D  KWH      34.32 2019-08-30 00:30:00
# 9   0330174190  7241403005           D  KWH      38.64 2019-08-30 00:45:00
# 10  0330174190  7241403005           D  KWH      27.48 2019-08-30 01:00:00
# 11  0330174190  7241403005           D  KWH      15.72 2019-08-30 01:15:00
# 12  0330174190  7241403005           D  KWH       5.52 2019-08-30 01:30:00
# 13  0330174190  7241403005           D  KWH      29.28 2019-08-30 01:45:00
# 14  0330174190  7241403005           D  KWH      29.28 2019-08-30 02:00:00
# 15  0330174190  7241403005           D  KWH      31.20 2019-08-30 02:15:00
# 16  0330174190  7241403005           D  KWH      21.60 2019-08-30 02:30:00
# 17  0330174190  7241403005           D  KWH      16.68 2019-08-30 02:45:00
# 18  0330174190  7241403005           D  KWH      13.32 2019-08-30 03:00:00
# 19  0330174190  7241403005           D  KWH      14.76 2019-08-30 03:15:00
# 20  0330174190  7241403005           D  KWH      14.04 2019-08-30 03:30:00
# 21  0330174190  7241403005           D  KWH      15.60 2019-08-30 03:45:00
#
#           date  hour
# 7   2019-08-30     0
# 8   2019-08-30     0
# 9   2019-08-30     0
# 10  2019-08-30     1
# 11  2019-08-30     1
# 12  2019-08-30     1
# 13  2019-08-30     1
# 14  2019-08-30     2
# 15  2019-08-30     2
# 16  2019-08-30     2
# 17  2019-08-30     2
# 18  2019-08-30     3
# 19  2019-08-30     3
# 20  2019-08-30     3
# 21  2019-08-30     3
