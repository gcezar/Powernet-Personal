# %%
import requests, json, time, datetime
username = 'gcezar@stanford.edu'
password = 'wjKlamp7FXsrdpi'
url = 'https://slac.powerflex.com:9443/login'
data = json.dumps({"username":username, "password":password})
headers = {'cache-control': 'no-cache', 'content-type': 'application/json',}
resp = requests.post(url, headers=headers, data=data)

# %%
token = json.loads(resp.text)['access_token']
start = int(datetime.datetime(2020,1,10,8,0).timestamp())
end = int(datetime.datetime(2020,1,10,12,0).timestamp())
data = json.dumps({"measurement":"ct_response", "time_filter":[start,end]})
# data = json.dumps({"name":"DCM_EVSE_Allocation"})
auth_token = 'Bearer '+ token
headers = {'cache-control': 'no-cache', 'content-type': 'application/json','Authorization':auth_token,}
# url_measurement = 'https://slac.powerflex.com:9443/get_measurement_data'
url_measurement = 'https://slac.powerflex.com:9443/get_csh/'
r = requests.post(url_measurement, headers=headers, data=data)

# %%
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJlMzMxNzk5Yi1mYjJmLTRmYTYtYTlmYS0wNDM4NWFmYzE3NmUiLCJleHAiOjE1ODM1NDIwNzUsImZyZXNoIjpmYWxzZSwiaWF0IjoxNTgzNDU1Njc1LCJ0eXBlIjoiYWNjZXNzIiwibmJmIjoxNTgzNDU1Njc1LCJpZGVudGl0eSI6ImdjZXphckBzdGFuZm9yZC5lZHUifQ.jZFi90iqpkxS6Qbrd3fPycd_g8qJUvQ_CiwdtYd-xJk'

# %%
import s3fs, boto3
import pandas as pd
import numpy as np
import requests, json, time, datetime
import matplotlib.pyplot as plt
from io import StringIO 
import boto3

# %%
s3_resource = boto3.resource('s3')
username = 'gcezar@stanford.edu'
password = 'wjKlamp7FXsrdpi'
data_login = json.dumps({"username":username, "password":password})
headers = {'cache-control': 'no-cache', 'content-type': 'application/json',}
url_login = 'https://slac.powerflex.com:9443/login'
resp_login = requests.post(url_login, headers=headers, data=data_login)

url_archive = 'https://archive.powerflex.com/login'
resp_archive = requests.post(url_archive, headers=headers, data=data_login)
token_meas = json.loads(resp_login.text)['access_token']
auth_token_meas = 'Bearer '+ token_meas
headers_meas = {'cache-control': 'no-cache', 'content-type': 'application/json','Authorization':auth_token_meas,}
url_measurement = 'https://slac.powerflex.com:9443/get_measurement_data'

token_arch = json.loads(resp_archive.text)['access_token']
auth_token_arch = 'Bearer '+ token_arch
headers = {'cache-control': 'no-cache', 'content-type': 'application/json','Authorization':auth_token_arch,}
url_arch1 = 'https://archive.powerflex.com/get_csh/0032/01'
url_arch2 = 'https://archive.powerflex.com/get_csh/0032/02'

month = 2
day = 3
hour_set = [12, 23]
start = int(datetime.datetime(2020, int(month), int(day), hour_set[0], 0).timestamp())
end = int(datetime.datetime(2020, int(month), int(day), hour_set[1], 0).timestamp())
data_meas = json.dumps({"measurement":"ct_response", "time_filter":[start,end]})
data_in = json.dumps({"startTime":start, "stopTime":end, "filterBy":"sessionStopTime", "anonymize":True})
r2 = requests.post(url_arch1, headers=headers, data=data_in)
r3 = requests.post(url_arch2, headers=headers, data=data_in)
data2 = json.loads(r2.text)
df2 = pd.DataFrame(data2['sessions'])
data3 = json.loads(r3.text)
df3 = pd.DataFrame(data3['sessions'])
data2
# Out:
# {'sessions': [{'WhDelivered': 16360,
#    'WhPerMile': 250,
#    'chargeSessionId': '33_70_200_914_2020-02-03 15:56:56.717074',
#    'doneChargingNotificationSent': True,
#    'driverId': 1266,
#    'driverIsExempt': False,
#    'evConnectionTime': '2020-02-03T15:56:57Z',
#    'milesNeeded': 80,
#    'minutesAvailable': 308,
#    'modifiedAt': '2020-02-03T20:13:01Z',
#    'sessionStartTime': '2020-02-03T15:57:06Z',
#    'sessionStopTime': '2020-02-03T20:13:01Z',
#    'siteId': 33,
#    'spaceId': 'B950-08',
#    'stationId': '33-70-200-914',
#    'subSiteId': 70,
#    'userStopped': False,
#    'wasOffline': False},
#   {'WhDelivered': 14832,
#    'WhPerMile': 300,
#    'chargeSessionId': '33_70_200_910_2020-02-03 15:10:50.212875',
#    'doneChargingNotificationSent': True,
#    'driverId': 2256,
#    'driverIsExempt': False,
#    'evConnectionTime': '2020-02-03T15:10:50Z',
#    'milesNeeded': 50,
#    'minutesAvailable': 206,
#    'modifiedAt': '2020-02-03T20:16:22Z',
# ...
